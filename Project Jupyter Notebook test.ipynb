# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Joël ACHIEPO**, chef projet

# %% [markdown]
# _I am interested in data science because is a new field of work that augments traditional analytical capabilities to help businesses make informed decisions. It relies for this on useful data and can only be applied in certain specific problems._

# %% [markdown]
# ### calculation test with code

# %%
56-(10*23*6*4)//271
# Out:
# 36

# %% [markdown]
# |Bulleted list|Numbered list|Tables|Hyperlinks|Images|
# |-------------|-------------|------|----------|------|
